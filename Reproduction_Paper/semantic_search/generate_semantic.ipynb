# %%
import pickle
with open('semantic_id_map.pkl','rb') as outf:
    id_dict=pickle.load(outf)
    # print(id_dict['22426'])
    # print(id_dict['103919'])
    # print(id_dict['10024'])
    print(len(id_dict))

    # print(id_dict['0'])
    cnt=0
    for tmp_id in id_dict:
        print(id_dict[tmp_id]+' '+tmp_id)
        
        cnt+=1
        if cnt>=100:
            assert 1==3
# Out:
# 3000
# 000 102853
# 001 13371
# 002 22426
# 003 215263
# 004 288824
# 005 166043
# 006 263505
# 007 296421
# 008 280784
# 009 197287
# 0010 212748
# 0011 63836
# 0012 79911
# 0013 267693
# 0014 90859
# 0015 53019
# 0016 179876
# 0017 294495
# 0018 216785
# 0019 306884
# 0020 95588
# 0021 156294
# 0022 12028
# 0023 142519
# 0024 177168
# 0025 49555
# 0026 289480
# 0027 197057
# 0028 41339
# 0029 122145
# 0030 57977
# 0031 76423
# 0032 252665
# 0033 95894
# 0034 102459
# 0035 15017
# 0036 118630
# 0037 289199
# 0038 306378
# 0039 249680
# 0040 176684
# 0041 265305
# 0042 29136
# 0043 143807
# 0044 32646
# 0045 140304
# 0046 166092
# 010 78393
# 011 174650
# 012 157863
# 013 251651
# 014 194888
# 015 272408
# 016 41834
# 017 162254
# 018 238748
# 019 275246
# 0110 117292
# 0111 153496
# 0112 37496
# 0113 307270
# 0114 212216
# 0115 107432
# 0116 199170
# 0117 60820
# 0118 4613
# 0119 147182
# 0120 266351
# 0121 39634
# 0122 68237
# 0123 124469
# 0124 53409
# 020 251326
# 021 245309
# ...
